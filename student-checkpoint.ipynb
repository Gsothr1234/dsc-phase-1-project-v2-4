# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Sadi Kiri
# * Student pace: full time
# * Scheduled project review date/time: 9/15/2023
# * Instructor name:
# * Blog post URL:

# %%
#import sqlite3, pandas and matplotlib.pyplot modules
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt

# %%
#create connection and cursor to SQlite database for imdb
conn = sqlite3.connect('zippedData/im.db/im.db')
cur = conn.cursor()

# %%
#For the next step we preview the contents for the movie_basics table
table_names = '''SELECT name as 'Table Name' FROM sqlite_master;'''
pd.read_sql(table_names,conn)
# Out:
#       Table Name
# 0   movie_basics
# 1      directors
# 2      known_for
# 3     movie_akas
# 4  movie_ratings
# 5        persons
# 6     principals
# 7        writers

# %%
# For the next step we view the data in table movie_basics and save as a Dataframe named df1
query1 = '''SELECT * FROM movie_basics'''
df1 = pd.read_sql(query1,conn)
df1
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres
# 0                 175.0    Action,Crime,Drama
# 1                 114.0       Biography,Drama
# 2                 122.0                 Drama
# 3                   NaN          Comedy,Drama
# 4                  80.0  Comedy,Drama,Fantasy
# ...                 ...                   ...
# 146139            123.0                 Drama
# 146140              NaN           Documentary
# 146141              NaN                Comedy
# 146142            116.0                  None
# 146143              NaN           Documentary
#
# [146144 rows x 6 columns]

# %%
#checking for null values
null= df1.isnull().sum()
null
df1.drop(columns=['runtime_minutes'],inplace=True)

# %% [markdown]
# Here we see we have the columns movie_id,primary_title,original_title,start_year,runtime_minutes and genres of note is that the primary_title is not always original_title and not all values for runtime and genre are filled

# %%
# For the next step we view the data in table movie_ratings
query2 = '''SELECT * FROM movie_ratings'''
df2 = pd.read_sql(query2,conn)
df2
# Out:
#          movie_id  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
#checking for null values
null= df2.isnull().sum()
null
# Out:
# movie_id         0
# averagerating    0
# numvotes         0
# dtype: int64

# %% [markdown]
# Next step is to merge the two dataframes as we can see they share the same column movie_id also to note is that the dataframes are not the same shape as about half the movies in the imdb database appear to not have ratings

# %%
# First we can see for both data_sets movie_id is not the index

imdb = pd.merge(df1,df2, on ='movie_id')
imdb.set_index('movie_id', inplace=True)
imdb
# Out:
#                              primary_title              original_title  \
# movie_id
# tt0063540                        Sunghursh                   Sunghursh
# tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# tt0069049       The Other Side of the Wind  The Other Side of the Wind
# tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# tt0100275         The Wandering Soap Opera       La Telenovela Errante
# ...                                    ...                         ...
# tt9913084                 Diabolik sono io            Diabolik sono io
# tt9914286                Sokagin Çocuklari           Sokagin Çocuklari
# tt9914642                        Albatross                   Albatross
# tt9914942       La vida sense la Sara Amat  La vida sense la Sara Amat
# tt9916160                       Drømmeland                  Drømmeland
#
#            start_year                genres  averagerating  numvotes
# movie_id
# tt0063540        2013    Action,Crime,Drama            7.0        77
# tt0066787        2019       Biography,Drama            7.2        43
# tt0069049        2018                 Drama            6.9      4517
# tt0069204        2018          Comedy,Drama            6.1        13
# tt0100275        2017  Comedy,Drama,Fantasy            6.5       119
# ...               ...                   ...            ...       ...
# tt9913084        2019           Documentary            6.2         6
# tt9914286        2019          Drama,Family            8.7       136
# tt9914642        2017           Documentary            8.5         8
# tt9914942        2019                  None            6.6         5
# tt9916160        2019           Documentary            6.5        11
#
# [73856 rows x 6 columns]

# %%
null= imdb.isnull().sum()
null
# Out:
# primary_title       0
# original_title      0
# start_year          0
# genres            804
# averagerating       0
# numvotes            0
# dtype: int64

# %%
#For missing genres
imdb['genres'] = imdb['genres'].fillna('Unknown')
imdb
# Out:
#                              primary_title              original_title  \
# movie_id
# tt0063540                        Sunghursh                   Sunghursh
# tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# tt0069049       The Other Side of the Wind  The Other Side of the Wind
# tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# tt0100275         The Wandering Soap Opera       La Telenovela Errante
# ...                                    ...                         ...
# tt9913084                 Diabolik sono io            Diabolik sono io
# tt9914286                Sokagin Çocuklari           Sokagin Çocuklari
# tt9914642                        Albatross                   Albatross
# tt9914942       La vida sense la Sara Amat  La vida sense la Sara Amat
# tt9916160                       Drømmeland                  Drømmeland
#
#            start_year                genres  averagerating  numvotes
# movie_id
# tt0063540        2013    Action,Crime,Drama            7.0        77
# tt0066787        2019       Biography,Drama            7.2        43
# tt0069049        2018                 Drama            6.9      4517
# tt0069204        2018          Comedy,Drama            6.1        13
# tt0100275        2017  Comedy,Drama,Fantasy            6.5       119
# ...               ...                   ...            ...       ...
# tt9913084        2019           Documentary            6.2         6
# tt9914286        2019          Drama,Family            8.7       136
# tt9914642        2017           Documentary            8.5         8
# tt9914942        2019               Unknown            6.6         5
# tt9916160        2019           Documentary            6.5        11
#
# [73856 rows x 6 columns]

# %% [markdown]
# Next we view the box office mojo database

# %%
df3 = pd.read_csv('zippedData/bom.movie_gross.csv.gz')
df3
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# 0        652000000  2010
# 1        691300000  2010
# 2        664300000  2010
# 3        535700000  2010
# 4        513900000  2010
# ...            ...   ...
# 3382           NaN  2018
# 3383           NaN  2018
# 3384           NaN  2018
# 3385           NaN  2018
# 3386           NaN  2018
#
# [3387 rows x 5 columns]

# %%
#As they both have year we will keep only one column for year to avoid duplicates
imdb.drop(columns=['start_year'],inplace=True)

# %%
null= df3.isnull().sum()
null
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %%
#Next we merge the two tables 
combdf = imdb.merge(df3, left_on='primary_title',right_on='title')
combdf.drop('title',axis=1,inplace=True)
combdf
# Out:
#                         primary_title                   original_title  \
# 0                               Wazir                            Wazir
# 1                         On the Road                      On the Road
# 2                         On the Road                      On the Road
# 3                         On the Road                      On the Road
# 4     The Secret Life of Walter Mitty  The Secret Life of Walter Mitty
# ...                               ...                              ...
# 3022                  The Chambermaid                     La camarista
# 3023           How Long Will I Love U            Chao shi kong tong ju
# 3024                  Helicopter Eela                  Helicopter Eela
# 3025                      Last Letter                   Ni hao, Zhihua
# 3026        Burn the Stage: The Movie        Burn the Stage: The Movie
#
#                        genres  averagerating  numvotes     studio  \
# 0          Action,Crime,Drama            7.1     15378    Relbig.
# 1     Adventure,Drama,Romance            6.1     37886        IFC
# 2                       Drama            6.0         6        IFC
# 3                       Drama            5.7       127        IFC
# 4      Adventure,Comedy,Drama            7.3    275300        Fox
# ...                       ...            ...       ...        ...
# 3022                    Drama            7.1       147         FM
# 3023                  Romance            6.5       607      WGUSA
# 3024                    Drama            5.4       673       Eros
# 3025            Drama,Romance            6.4       322         CL
# 3026        Documentary,Music            8.8      2067  Trafalgar
#
#       domestic_gross foreign_gross  year
# 0          1100000.0           NaN  2016
# 1           744000.0       8000000  2012
# 2           744000.0       8000000  2012
# 3           744000.0       8000000  2012
# 4         58200000.0     129900000  2013
# ...              ...           ...   ...
# 3022           300.0           NaN  2015
# 3023        747000.0      82100000  2018
# 3024         72000.0           NaN  2018
# 3025        181000.0           NaN  2018
# 3026       4200000.0      16100000  2018
#
# [3027 rows x 9 columns]

# %% [markdown]
# We can see we have duplicates

# %%
#Check datatypes of columns in dataframe
combdf.dtypes
# Out:
# primary_title      object
# original_title     object
# genres             object
# averagerating     float64
# numvotes            int64
# studio             object
# domestic_gross    float64
# foreign_gross      object
# year                int64
# dtype: object

# %%
#Next is to create a new column for total revenue first identify structure of column foreign_gross
q=combdf['foreign_gross'].unique()
print(q)
# Out:
# [nan '8000000' '129900000' ... '49400000' '542100000' '82100000']

# %%
# convert foreign_gross to int
combdf['foreign_gross'] = combdf['foreign_gross'].astype(str)
combdf['foreign_gross'] = combdf['foreign_gross'].str.replace(',','')
combdf['foreign_gross'] = combdf['foreign_gross'].replace('nan','0')
combdf['foreign_gross']= combdf['foreign_gross'].astype(float)
#Create new total_gross column
combdf['total_gross']= combdf['foreign_gross'] + combdf['domestic_gross']

# %%
#Next check for duplicates
duplicate = combdf[combdf.duplicated()]
duplicate
combdf.drop_duplicates()
# Out:
#                         primary_title                   original_title  \
# 0                               Wazir                            Wazir
# 1                         On the Road                      On the Road
# 2                         On the Road                      On the Road
# 3                         On the Road                      On the Road
# 4     The Secret Life of Walter Mitty  The Secret Life of Walter Mitty
# ...                               ...                              ...
# 3022                  The Chambermaid                     La camarista
# 3023           How Long Will I Love U            Chao shi kong tong ju
# 3024                  Helicopter Eela                  Helicopter Eela
# 3025                      Last Letter                   Ni hao, Zhihua
# 3026        Burn the Stage: The Movie        Burn the Stage: The Movie
#
#                        genres  averagerating  numvotes     studio  \
# 0          Action,Crime,Drama            7.1     15378    Relbig.
# 1     Adventure,Drama,Romance            6.1     37886        IFC
# 2                       Drama            6.0         6        IFC
# 3                       Drama            5.7       127        IFC
# 4      Adventure,Comedy,Drama            7.3    275300        Fox
# ...                       ...            ...       ...        ...
# 3022                    Drama            7.1       147         FM
# 3023                  Romance            6.5       607      WGUSA
# 3024                    Drama            5.4       673       Eros
# 3025            Drama,Romance            6.4       322         CL
# 3026        Documentary,Music            8.8      2067  Trafalgar
#
#       domestic_gross  foreign_gross  year  total_gross
# 0          1100000.0            0.0  2016    1100000.0
# 1           744000.0      8000000.0  2012    8744000.0
# 2           744000.0      8000000.0  2012    8744000.0
# 3           744000.0      8000000.0  2012    8744000.0
# 4         58200000.0    129900000.0  2013  188100000.0
# ...              ...            ...   ...          ...
# 3022           300.0            0.0  2015        300.0
# 3023        747000.0     82100000.0  2018   82847000.0
# 3024         72000.0            0.0  2018      72000.0
# 3025        181000.0            0.0  2018     181000.0
# 3026       4200000.0     16100000.0  2018   20300000.0
#
# [3027 rows x 10 columns]

# %% [markdown]
# Next we will attempt to see which genres achieve the highest revenue and thus more likely to be profitable if Microsoft attempt

# %%
#Check number of different unique genres
q=combdf['genres'].nunique()
print(q)
# Out:
# 323

# %%
#First consider only the first word in genre as the primary identifier
combdf['first_genres'] = combdf['genres'].str.split(',').str[0]

#Group by genre then sum to get total revenue per genre
genres_totals = combdf.groupby('first_genres')['total_gross'].sum().reset_index()

#Create Barplot
plt.figure(figsize =(10,6))
plt.bar(genres_totals['first_genres'], genres_totals['total_gross'])
plt.xlabel('Genres')
plt.ylabel('Total Gross Revenue')
plt.title('Total Gross Revenue by Genre')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# This barchart gives us an idea of the types of movies that are most likely to succeed with action, adventure comedy and drama being the biggest earners

# %%
# To get number of votes by genre
genres_popularity = combdf.groupby('first_genres')['numvotes'].sum().reset_index()

#creating a plot
plt.figure(figsize =(10,6))
plt.bar(genres_popularity['first_genres'],genres_popularity['numvotes'] )
plt.xlabel('Genre')
plt.ylabel('Number of Votes')
plt.title('Number of Votes by Genre')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# We can further explore this data by viewing a barcount of movies by genre

# %%
#calculate movie count by genre
genres_count = combdf['first_genres'].value_counts().reset_index()
genres_count.columns = ['first_genres', 'movie_count']
#Create Barplot
plt.figure(figsize =(10,6))
plt.bar(genres_count['first_genres'], genres_count['movie_count'])
plt.xlabel('Genres')
plt.ylabel('No of Movies')
plt.title('No of Movies by Genre')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# here we can see that surprisingly Action is not the highest despite raising the largest revenue by a significant margin meaning some films are very high earners leading to the graph we saw earlier the most made films are drama action comedy and biography

# %% [markdown]
# Next we can check the overall growth state of the industry by tracking revenue per year

# %%
#Group by year then sum to get total revenue per year
revenue_per_year = combdf.groupby('year')['total_gross'].sum().reset_index()

#Create linegrap
plt.figure(figsize =(10,6))
plt.plot(revenue_per_year['year'], revenue_per_year['total_gross'])
plt.xlabel('Year')
plt.ylabel('Total Gross Revenue')
plt.title('Total Gross Revenue by Year')
plt.show()

# %% [markdown]
# It seems the growth is not as stable as expected however despite dips there is a general upward trend.

# %%
#To count number of movies made per year
movies_per_year = combdf['year'].value_counts().sort_index()

#Create barplot
plt.figure(figsize =(10,6))
plt.plot(movies_per_year.index, movies_per_year.values)
plt.xlabel('Year')
plt.ylabel('Number of Movies')
plt.title('Movies per Year')
plt.show()

# %% [markdown]
# We can check the pearson correlation between average rating and total gross to see if there is any correlation between the two

# %%
correlation = combdf['averagerating'].corr(combdf['total_gross'])
correlation
# Out:
# 0.11630317505722072

# %% [markdown]
# This shows a weak positive correlation between average ratings and total gross

# %%
#To get an idea of the top studios in the market

studio_revenue = combdf.groupby('studio')['total_gross'].sum().reset_index()
studio_revenue = studio_revenue.sort_values(by='total_gross', ascending=False)
studio_revenue.head()
# Out:
#     studio   total_gross
# 32      BV  4.256875e+10
# 198   Uni.  3.182447e+10
# 81     Fox  3.047577e+10
# 206     WB  2.609310e+10
# 181   Sony  1.821806e+10
